# %% [markdown]
#    <H2> <font color='green'> Ibtissem Maoui 3DNI1 </font> </H2>
#     <H1><center><font color='Yellow'> **Classification of Tweets** </font></center></H1>

# %% [markdown]
# # 1. Extraction of Tweets

# %%
# !pip install tweepy

# %%
#Géneral
import os
import tweepy as tw   #to consume twitter's API
import pandas as pd   #to handle data
import numpy as np   #for number computing
from tweepy import OAuthHandler

#For politting and vizualisation
from IPython.display import display
import seaborn as sns
# %matplotlib inline

# %%
consumer_key = '6PuHNdjb7PfniWOH5snA7tGRR'
consumer_secret = 'cFtNNEkfyvbscGY3euLJ269htrtuhAKzM54UcfILdvAWn1qRms'

access_token = '1330066673823571971-5pNacJFlgLSgnNykylmoEk2DTdp130'
access_token_secret = 'XlpzovGuRDHNS9l1aHvugtC0RuV1jfeD3t1gHFJp9HI4o'

# %%
# Creating the authentication object
auth = tw.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tw.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# * ### Sport_tweets:

# %%
search_words1= "Sport"
date_since = "2019-02-01"

# %%
tweets=[]
for tweet in tw.Cursor(api.search,
                      q=search_words1,
                      lang="en",
                      since=date_since).items(3000):
    tweets.append(tweet)
#Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# @telegraph_sport @FatimaKdouh_ Paul who? #InHookWeTrust #redv
# Craig MacGillivray, what a save. Big chance. #Pompey https://t.co/i0h3dSrlrF
# @CoachHolst That's why 4 short seasons w/ some start/end dates bleeding into other seasons. I'm sure I'm missing a… https://t.co/moHHVMkQzJ
# RT @bloominanna: “..I cannot think of a better metaphor for the dominant regressive so-called progressivism of our time than a 41-year-old…
# RT @DuncanBrowneJPI: Josh Askew unveiled by new club after leaving Boston United https://t.co/bcwNqc0DSp
# Please God don't make me like this sport abeg... I don dey research rules
# RT @JLCBasketball: Our international student-athletes at @JohnLeggottColl bring so much to our team, Michael joined us from Hong Kong 🇭🇰 th…
# RT @CastorTroySRB: Some of my favourite pictures from this amazing sport of war https://t.co/5aHeRdR5x7
# RT @trboxing: Congratulations to @andreward on his upcoming 2021 induction into the @BoxingHall!
#
# ...

# %%
def ToDataframeTweets(tweets):
    TweetsDF = pd.DataFrame()
    TweetsDF['ID'] = [tweet.id for tweet in tweets]
    TweetsDF['Tweets'] = [tweet.text for tweet in tweets]
    TweetsDF.to_csv('Dataset/tweets1.csv')
    
    return TweetsDF

# %%
TweetsDF = ToDataframeTweets(tweets)
TweetsDF.head(3000)
# Out:
#                        ID                                             Tweets
# 0     1338960279162347522  @telegraph_sport @FatimaKdouh_ Paul who? #InHo...
# 1     1338960273877704711  Craig MacGillivray, what a save. Big chance. #...
# 2     1338960271008665600  @CoachHolst That's why 4 short seasons w/ some...
# 3     1338960265811996672  RT @bloominanna: “..I cannot think of a better...
# 4     1338960249278111745  RT @DuncanBrowneJPI: Josh Askew unveiled by ne...
# ...                   ...                                                ...
# 2995  1338943412515590147  RT @guardian: Azeem Rafiq files race discrimin...
# 2996  1338943406945366016  i used to bind my chest in middle school with ...
# 2997  1338943400666664968               CLOSE! #nffc https://t.co/4BLVer8AVS
# 2998  1338943387370745859  @BristolBears @RavenscroftGB @Bristol_Sport Ph...
# 2999  1338943386225528833  RT @thearibradford: So is holding grudges an O...
#
# [3000 rows x 2 columns]

# %% [markdown]
# * ### Music_tweets:

# %%
search_words2= "Music"
date_since = "2019-01-01"

# %%
tweets=[]
for tweet in tw.Cursor(api.search,
                      q=search_words2,
                      lang="en",
                      since=date_since).items(2000):
    tweets.append(tweet)
#Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# 0267185321.... Whatsapp me make we vyb😉 abeg girls only 😂😂
# RT @collins_reignss: Whenever I listen to Michael Jackson’s music I always feel something burning within me. That guy wasn’t a human trust…
# Music
# 💃🔥
#
# https://t.co/URiCm6omit
# RT @ringtonebangers: Many of the Samsung Galaxy S III's alarms are, dare I say, genuinely beautiful, emotional pieces of music. (no, that d…
# RT @awsten: SOME DIRECTING SOME SINGING, NEW POP UP LOWKEY AS HELL MUSIC VIDEO OUT NOW
#
# 👁: https://t.co/JJV5DvWUW5 https://t.co/YY7fwOq04s
# blackpink make music for pretty young people so if the music not hitting for you............
# @jakemogg2 @__georgialucy Yeah I can imagine how dare she insult your music 😂
# RT @Uncle_Benz_: What’s the music to listen to in this car? https://t.co/KfULmnmw8n
# @sexcnigger @Helenaa1994 @Nlechoppa1 I agree with you. He’s convincing all sorts of impressionable, gullible people… https://t.co/35INjfOS0q
# so columbia
#
# - didn’t wish lauren a happy birthday
# ...

# %%
def ToDataframeTweets(tweets):
    TweetsDF = pd.DataFrame()
    TweetsDF['ID'] = [tweet.id for tweet in tweets]
    TweetsDF['Tweets'] = [tweet.text for tweet in tweets]
    TweetsDF.to_csv('tweets2.csv')
    
    return TweetsDF

# %%
TweetsDF = ToDataframeTweets(tweets)
TweetsDF.head(2000)
# Out:
#                        ID                                             Tweets
# 0     1338964960710373379  0267185321.... Whatsapp me make we vyb😉 abeg g...
# 1     1338964958781059072  RT @collins_reignss: Whenever I listen to Mich...
# 2     1338964958529253376               Music\n💃🔥\n\nhttps://t.co/URiCm6omit
# 3     1338964958386728960  RT @ringtonebangers: Many of the Samsung Galax...
# 4     1338964957606645760  RT @awsten: SOME DIRECTING SOME SINGING, NEW P...
# ...                   ...                                                ...
# 1995  1338963696270241792  RT @marcosuchima: Queen Evelynn sketch! 😔🙏 now...
# 1996  1338963696215715841  RT @triviadance: after dynamite becomes the mo...
# 1997  1338963696060686336  @TheClapperton @EASPORTSNHL GM connected and b...
# 1998  1338963695683047424  RT @Michaelraymusic: Taking y'all behind the s...
# 1999  1338963695582367745  what are some songs/artists that uplift ur moo...
#
# [2000 rows x 2 columns]

# %% [markdown]
# * ### Theater_tweets:

# %%
search_words3= "Theater"
date_since = "2019-01-01"

# %%
tweets=[]
for tweet in tw.Cursor(api.search,
                      q=search_words3,
                      lang="en",
                      since=date_since).items(2000):
    tweets.append(tweet)
#Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# RT @dhami: A sweetheart "straight ally" the year below me visited NYU (intended major: musical theater) his last year of HS, and his mom as…
# RT @warrenleightTV: Every actor and writer in New York owes a debt to the West Bank Cafe.  If you can,  now is the time to repay it.
#
# Save…
# Watching Dr. Jim Ducanto @jducanto on @refresh2021 #refresh2021 I realized I need a theater cap for my future zoom… https://t.co/leNqjegqhS
# @taradublinrocks @Amtrak Amtrak One! Boarded by proud boys and Joe &amp; Dr. Jill throw them all from the train.
# I'd ev… https://t.co/1q8Rezwfmk
# RT @premierguitar: Watch @TaylorGuitars master builder Andy Powers shows off a portable yet potent new 24 1/8”-scale flattop with eco-frien…
# @AnnaVeganista @Libertarianwit1 @SaraGonzalesTX Masks are worthless, but that is for the store to enforce and not s… https://t.co/ONFluUNwQW
# star wars? pfft no thanks, i’m not into that nerd shit *puts on a dream theater record*
# ...

# %%
def ToDataframeTweets(tweets):
    TweetsDF = pd.DataFrame()
    TweetsDF['ID'] = [tweet.id for tweet in tweets]
    TweetsDF['Tweets'] = [tweet.text for tweet in tweets]
    TweetsDF.to_csv('Dataset/tweets3.csv')
    
    return TweetsDF

# %%
TweetsDF = ToDataframeTweets(tweets)
TweetsDF.head(2000)
# Out:
#                        ID                                             Tweets
# 0     1338965677420503047  RT @dhami: A sweetheart "straight ally" the ye...
# 1     1338965665206722566  RT @warrenleightTV: Every actor and writer in ...
# 2     1338965656419622914  Watching Dr. Jim Ducanto @jducanto on @refresh...
# 3     1338965649880723458  @taradublinrocks @Amtrak Amtrak One! Boarded b...
# 4     1338965644427948032  RT @premierguitar: Watch @TaylorGuitars master...
# ...                   ...                                                ...
# 1995  1338926411411812357  @Dan_Sacharow Obviously I dig the MCU..but it'...
# 1996  1338926375324053505  @Sean_OConnell The Exorcist.  Seeing footage o...
# 1997  1338926316259663872  @TeaPainUSA Idiots. If they really are upset a...
# 1998  1338926312933765120  RT @WashletJP: Thinking about the poster Tokyo...
# 1999  1338926276212449280  4 years ago today we were heading to watch Rog...
#
# [2000 rows x 2 columns]

# %% [markdown]
# * ### Dance_tweets:

# %%
search_words4= "dance"
date_since = "2019-01-01"

# %%
tweets=[]
for tweet in tw.Cursor(api.search,
                      q=search_words4,
                      lang="en",
                      since=date_since).items(2000):
    tweets.append(tweet)
#Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# Pretty little things on Netflix is amazing, especially recommend if you were a dance academy fan (rip sammie) it’s… https://t.co/jpnNGBQ9g3
# RT @wildhorserockuk: "CAN'T STOP (MEETING ON THE DANCE FLOOR)" - Out This Thursday
#
# “You can’t beat a bit of the prolific Wild Horse from…
# RT @HatfieldAnne: Now really, why put the manger in the center of the nativity? Leave the middle open for the dance floor.
# @gc_rch @danielcolombopr I and many others are fans of your concept of the "DANCE", so let's add the skill to perfecting the "DANCE" Georges
# Dance like people wish they weren’t watching, clean like you are mad at the world and not afraid to show it - alway… https://t.co/U1J7FuyeAv
# RT @cherrycola9107: Famous Chinese Boyband Group R1SE members Xia Zhiguang and Zhao Rang cover dance to (KAI) Kim Jong In’s latest single "…
# #NOWPLAYING Tech N9ne - Hiccup
#
# CLICK TO LISTEN ➡️ https://t.co/vOgEUK2yXd
#
# #freqnetwork #rock #pop #hiphopmusic… https://t.co/KvaS9yX0Xh
# ...

# %%
def ToDataframeTweets(tweets):
    TweetsDF = pd.DataFrame()
    TweetsDF['ID'] = [tweet.id for tweet in tweets]
    TweetsDF['Tweets'] = [tweet.text for tweet in tweets]
    TweetsDF.to_csv('Dataset/tweets4.csv')
    
    return TweetsDF

# %%
TweetsDF = ToDataframeTweets(tweets)
TweetsDF.head(2000)
# Out:
#                        ID                                             Tweets
# 0     1338968577567764481  Pretty little things on Netflix is amazing, es...
# 1     1338968575193780228  RT @wildhorserockuk: "CAN'T STOP (MEETING ON T...
# 2     1338968571737755650  RT @HatfieldAnne: Now really, why put the mang...
# 3     1338968563319631874  @gc_rch @danielcolombopr I and many others are...
# 4     1338968559943364610  Dance like people wish they weren’t watching, ...
# ...                   ...                                                ...
# 1995  1338962394505240576  Yes it certainly did ! 😂I tried to  dry  the b...
# 1996  1338962392772841472  RT @UsBlinksUnion: Let’s celebrate our barbie ...
# 1997  1338962391418032128                Anyone else dance when they eat? :3
# 1998  1338962383922982913  RT @FTWStudios99: Kariru\nWhat If Caulifla and...
# 1999  1338962378927517697  RT @OfficialMonstaX: 🎥\n201215 #몬스타엑스\n#Dance_...
#
# [2000 rows x 2 columns]

# %% [markdown]
# * ### Health_tweets:

# %%
search_words5= "health"
date_since = "2019-01-01"

# %%
tweets=[]
for tweet in tw.Cursor(api.search,
                      q=search_words5,
                      lang="en",
                      since=date_since).items(2000):
    tweets.append(tweet)
#Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# RT @Harry_Styles: Everyone’s health and safety remains our top priority, which is why I unfortunately have to postpone my UK and European s…
# RT @bhncdsb: COVID-19 NEWS: Positive COVID-19 cases info shared with @sjceagles https://t.co/bNudGCIyZr and @rescatholic https://t.co/8AXpn…
# Don't feel like this is the last season greeting in 2020, my prayer is that you have good luck, good health, and yo… https://t.co/KpOG5TBSNk
# RT @ThePaisano: TIS THE SEASON! 🎁
#
# The Paisano is currently accepting cashapp donations for toys that will  benefit the children of Univer…
# RT @uche_blackstock: Most people don't realize the weight on the minds &amp; hearts of Black healthcare and public health workers during this #…
# RT @ErikGriffin: Diet Culture!?!?!?!?!? See how these Idoits can make anything sound bad. What's next? Saving money becomes fiscally respon…
# ...

# %%
def ToDataframeTweets(tweets):
    TweetsDF = pd.DataFrame()
    TweetsDF['ID'] = [tweet.id for tweet in tweets]
    TweetsDF['Tweets'] = [tweet.text for tweet in tweets]
    TweetsDF.to_csv('Dataset/tweets5.csv')
    
    return TweetsDF

# %%
TweetsDF = ToDataframeTweets(tweets)
TweetsDF.head(2000)
# Out:
#                        ID                                             Tweets
# 0     1338972623414423555  RT @Harry_Styles: Everyone’s health and safety...
# 1     1338972620155473929  RT @bhncdsb: COVID-19 NEWS: Positive COVID-19 ...
# 2     1338972619954028544  Don't feel like this is the last season greeti...
# 3     1338972617135562758  RT @ThePaisano: TIS THE SEASON! 🎁 \n\nThe Pais...
# 4     1338972616904859652  RT @uche_blackstock: Most people don't realize...
# ...                   ...                                                ...
# 1995  1338971396941156352           RT @ossoff: HEALTH CARE IS A HUMAN RIGHT
# 1996  1338971396924432386  RT @Nnedi: health insurance in the united stat...
# 1997  1338971396903321601  RT @margie_deleon: Will I comply with the new ...
# 1998  1338971396836356098  RT @DefenceHQ: All armed forces will receive m...
# 1999  1338971396744110080  RT @Anaridis: Boston health care workers danci...
#
# [2000 rows x 2 columns]

# %%
search_words6= "cancer"
date_since = "2019-01-01"

# %%
tweets=[]
for tweet in tw.Cursor(api.search,
                      q=search_words6,
                      lang="en",
                      since=date_since).items(2000):
    tweets.append(tweet)
#Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# The fact that my big three placements are ...cancer says a lot
# RT @Sci_Phile: You simply must look at the best science images of the year. This is a cancer cell slashed open using an ion beam. https://t…
# There is nothing heartwarming about a nurse not having enough money or paid time off to liters battle cancer for he… https://t.co/KKCsBT3Ead
# @robjeffecology @donalds_fred @charwrites_ @nadinebh_ See there it is the excuses, I have not seen my own mother fo… https://t.co/bB5kKQTv9v
# RT @CurtisHouck: Everyone join me in praying for @KFILE, @RachelEnsignWSJ, and their beautiful little girl Francesca who's battling brain c…
# RT @ollysmithtravel: Are you suffering from Long Lockdown? Symptoms include unemployment, depression, poverty, anxiety, undiagnosed cancer,…
# The type and abundance of bacteria found in the mouth may be linked to lung cancer risk in non-smokers. Fewer speci… https://t.co/LOYBmsbqZG
# ...

# %%
def ToDataframeTweets(tweets):
    TweetsDF = pd.DataFrame()
    TweetsDF['ID'] = [tweet.id for tweet in tweets]
    TweetsDF['Tweets'] = [tweet.text for tweet in tweets]
    TweetsDF.to_csv('Dataset/tweets6.csv')
    
    return TweetsDF

# %%
TweetsDF = ToDataframeTweets(tweets)
TweetsDF.head(2000)
# Out:
#                        ID                                             Tweets
# 0     1338976257682321408  The fact that my big three placements are ...c...
# 1     1338976255169818624  RT @Sci_Phile: You simply must look at the bes...
# 2     1338976254582796288  There is nothing heartwarming about a nurse no...
# 3     1338976249516077057  @robjeffecology @donalds_fred @charwrites_ @na...
# 4     1338976249331388421  RT @CurtisHouck: Everyone join me in praying f...
# ...                   ...                                                ...
# 1995  1338970627072548864  RT @AshleyBanjo: CHECK YOURSELVES LADIES AND G...
# 1996  1338970625940054019  RT @AaliyahJay: My cancer sister ♋️ 💜 https://...
# 1997  1338970625377849344        @lauramellado A cure to my mothers cancer 😪
# 1998  1338970619212222464  RT @AshleyBanjo: CHECK YOURSELVES LADIES AND G...
# 1999  1338970618969133060  @GLS_OceanSoul they gave me: Het ? (Or bi i do...
#
# [2000 rows x 2 columns]

# %% [markdown]
# * ### DataScience_tweets:

# %%
search_words7= "Data science"
date_since = "2019-01-01"

# %%
tweets=[]
for tweet in tw.Cursor(api.search,
                      q=search_words7,
                      lang="en",
                      since=date_since).items(2000):
    tweets.append(tweet)
#Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# RT @MuckZuckerburg: POGCORN STARCRAFT PYTHON ARTIFICIAL INTELLIGENCE TO SLOW HONEY LIBERTARIANISM WOODWORKING GOOD DIARRHEA CLOWN POO PSORI…
# RT @SiAction: I've been honored and lucky to have worked with Epistemix to connect  their epidemiological models coupled with #ArcGIS Livin…
# RT @AceAILondon: Data Science Is A Team Sport. Pass It On!
#
# https://t.co/IzUJU7feSZ
#
# #Python #DEVCommunity #100DaysOfCode #MachineLearning…
# RT @AceAILondon: Data Science Is A Team Sport. Pass It On!
#
# https://t.co/IzUJU7feSZ
#
# #Python #DEVCommunity #100DaysOfCode #MachineLearning…
# RT @AceAILondon: Data Science Is A Team Sport. Pass It On!
#
# https://t.co/IzUJU7feSZ
#
# #Python #DEVCommunity #100DaysOfCode #MachineLearning…
# @blaine_bateman @kierisi You do this in data science?
# RT @FLAHAULT: An important paper in Science today which concludes: "We found a large effect for closing schools and universities in conjunc…
# ...

# %%
def ToDataframeTweets(tweets):
    TweetsDF = pd.DataFrame()
    TweetsDF['ID'] = [tweet.id for tweet in tweets]
    TweetsDF['Tweets'] = [tweet.text for tweet in tweets]
    TweetsDF.to_csv('Dataset/tweets7.csv')
    
    return TweetsDF

# %%
TweetsDF = ToDataframeTweets(tweets)
TweetsDF.head(2000)
# Out:
#                        ID                                             Tweets
# 0     1338976926271221760  RT @MuckZuckerburg: POGCORN STARCRAFT PYTHON A...
# 1     1338976924471857153  RT @SiAction: I've been honored and lucky to h...
# 2     1338976837456850947  RT @AceAILondon: Data Science Is A Team Sport....
# 3     1338976833900077063  RT @AceAILondon: Data Science Is A Team Sport....
# 4     1338976759623127046  RT @AceAILondon: Data Science Is A Team Sport....
# ...                   ...                                                ...
# 1995  1338883219605872641  RT @arstechnica: FDA releases data on Moderna’...
# 1996  1338883162894553088  RT @ELS_Radiology: Clinical application of the...
# 1997  1338883148566949888  VTexus are providing consultancy services in t...
# 1998  1338883121455001601  RT @warisali9199: @VTexus VTexus are providing...
# 1999  1338883110008582144  RT @envdatascience: OPEN FOR SUBMISSIONS: At #...
#
# [2000 rows x 2 columns]

# %%
#After getting access to Twitter data we’ll now create a file to save all the tweets in it.
import os
import glob
import pandas as pd
os.chdir('Dataset')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "allTweets.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# ##  Loading the Dataset

# %%
# importing libraries: numpy & pandas  
import pandas as pd
import numpy as np
# loading our Dataset 
TweetsDF= pd.read_csv("Dataset/allTweets.csv")
# display the first 100 elements of the dataframe:
display(TweetsDF.head(100))
# Out:
#     Unnamed: 0                   ID  \
# 0            0  1338960279162347522
# 1            1  1338960273877704711
# 2            2  1338960271008665600
# 3            3  1338960265811996672
# 4            4  1338960249278111745
# ..         ...                  ...
# 95          95  1338959753855307777
# 96          96  1338959751447601152
# 97          97  1338959731805859849
# 98          98  1338959718472167425
# 99          99  1338959713904504834
#
#                                                Tweets
# 0   @telegraph_sport @FatimaKdouh_ Paul who? #InHo...
# 1   Craig MacGillivray, what a save. Big chance. #...
# 2   @CoachHolst That's why 4 short seasons w/ some...
# 3   RT @bloominanna: “..I cannot think of a better...
# 4   RT @DuncanBrowneJPI: Josh Askew unveiled by ne...
# ..                                                ...
# 95  Man City get green light for Lionel Messi tran...
# 96  @AtanasioCharles @KyleJEngel @FireTrumpToday @...
# ...

# %%
# We create a pandas dataframe as TweetId and Tweet:
Tweets= TweetsDF[['ID','Tweets']]

# %%
print("shape:", Tweets.shape)
# We display the first 5 elements of the dataframe:
display(Tweets.head())
# Out:
# shape: (30000, 2)
#                     ID                                             Tweets
# 0  1338960279162347522  @telegraph_sport @FatimaKdouh_ Paul who? #InHo...
# 1  1338960273877704711  Craig MacGillivray, what a save. Big chance. #...
# 2  1338960271008665600  @CoachHolst That's why 4 short seasons w/ some...
# 3  1338960265811996672  RT @bloominanna: “..I cannot think of a better...
# 4  1338960249278111745  RT @DuncanBrowneJPI: Josh Askew unveiled by ne...

# %% [markdown]
# # 2. Preprocessing tweets (NLP)

# %% [markdown]
# This is one of the essential steps in any natural language processing (NLP) task. <br/>
# For this to work, there is a lot of processing that needs to be done.

# %% [markdown]
# ### Cleaning up tweets: <br/>
# * Removing hashtags, mentions, links and punctuation marks & converting tweets to lowercase to prevent algorithms from interpreting the same words.

# %%
#create  a function to clean the tweets
import re

def nlp_pipeline(text):

    text = text.lower()
    text = text.replace('\n', ' ').replace('\r', '')
    text = ' '.join(text.split())
    text = re.sub(r"rt[A-Za-z\.]*[0-9]+[A-Za-z%°\.]*", "", text)
    text = re.sub(r"(\s\-\s|-$)", "", text)
    text = re.sub(r"[,\!\?\%\(\)\/\"]", "", text)
    text = re.sub(r"\&\S*\s", "", text)
    text = re.sub(r"\&", "", text)
    text = re.sub(r"\+", "", text)
    text = re.sub(r"\#", "", text)
    text = re.sub(r"\$", "", text)
    text = re.sub(r"\£", "", text)
    text = re.sub(r"\%", "", text)
    text = re.sub(r"\:", "", text)
    text = re.sub(r"\@", "", text)
    text = re.sub(r"\-", "", text)
    text = re.sub(r"\_", "", text)
    text = re.sub(r"\'", "", text)
    text = re.sub(r"\"", "", text)
    text = re.sub(r"\“", "", text)
    text = re.sub(r"\.|^rt", "", text)

    return text

# %%
Tweets['Tweets'] = Tweets['Tweets'].apply(nlp_pipeline)
Tweets
# Out:
# <ipython-input-214-35a19f40bd50>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tweets['Tweets'] = Tweets['Tweets'].apply(nlp_pipeline)
#                         ID                                             Tweets
# 0      1338960279162347522  telegraphsport fatimakdouh paul who inhookwetr...
# 1      1338960273877704711  craig macgillivray what a save big chance pomp...
# 2      1338960271008665600  coachholst thats why 4 short seasons w some st...
# 3      1338960265811996672   bloominanna i cannot think of a better metaph...
# 4      1338960249278111745   duncanbrownejpi josh askew unveiled by new cl...
# ...                    ...                                                ...
# ...

# %%
# !pip install nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
#importing needed librairies 
import tweepy
import csv
import os
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import spacy
from sklearn.model_selection import train_test_split
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.tokenize import RegexpTokenizer, WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import string
from string import punctuation
import collections
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import en_core_web_sm

from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics.pairwise import cosine_similarity

# !pip3 install -U spacy
# !python3 -m spacy download en_core_web_sm

from sklearn.metrics import jaccard_score
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\My_Computing\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\My_Computing\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Tokenization, lemmatization and stop words removal

# %%
def preprocess_tweet_text(Tweets):
    Tweets.lower()
    # Remove urls
    Tweets = re.sub(r"http\S+|www\S+|https\S+", '', tweet, flags=re.MULTILINE)
    # Remove user @ references and '#' from tweet
    Tweets = re.sub(r"\@\w+|\#","", tweet)
    # Remove punctuations
    Tweets = Tweets.translate(str.maketrans('', '', string.punctuation))
    # Remove stopwords
    tweet_tokens = word_tokenize(Tweets)
    filtered_words = [w for w in tweet_tokens if not w in stop_words]
    
    #ps = PorterStemmer()
    #stemmed_words = [ps.stem(w) for w in filtered_words]
    lemmatizer = WordNetLemmatizer()
    lemma_words = [lemmatizer.lemmatize(w, pos='a') for w in stemmed_words]
    
    return " ".join(filtered_words)

# %%
Tweets.head(100)
# Out:
#                      ID                                             Tweets
# 0   1338960279162347522  telegraphsport fatimakdouh paul who inhookwetr...
# 1   1338960273877704711  craig macgillivray what a save big chance pomp...
# 2   1338960271008665600  coachholst thats why 4 short seasons w some st...
# 3   1338960265811996672   bloominanna i cannot think of a better metaph...
# 4   1338960249278111745   duncanbrownejpi josh askew unveiled by new cl...
# ..                  ...                                                ...
# 95  1338959753855307777  man city get green light for lionel messi tran...
# 96  1338959751447601152  atanasiocharles kylejengel firetrumptoday dine...
# 97  1338959731805859849   philhurst1 i am very proud to contribute to s...
# 98  1338959718472167425  ignorance of the crowd not giving one iota of ...
# 99  1338959713904504834  🆕 margs vs nsg mobo awards racism in sport 🗞 a...
#
# [100 rows x 2 columns]

# %%
#we delete the duplicate lines using drop_duplicates():
Tweets = Tweets.drop_duplicates()
print("shape:", Tweets.shape)
# Out:
# shape: (14899, 2)

# %% [markdown]
# # 3. Classification of tweets

# %%
 #Defining the set of words

# %%
Sport_related_words = ''' aerobics archer archery arena arrowathlete athletics axel sport

badminton ballbasebase ballbasketball batbaton batter batting biathlon bicycle bicycling bike biking billiards bobsleigh bocce boomerang boules bowbowler bowling boxer boxing bronzemedalbunt

canoe canoeing catch catcherchampion championship cleats club coach compete competingcompetition competitor crew cricket croquetcross countrycuecurling cyclecy cling cyclist

dart dartboard deadlifting decathlon defense diamond discus divediver divingdo dgeball doubleheader dugout

épéeequestrian equipment exercise

fencing field field hockey fielder fielding figure skatingfitness football forwardfree throwFrisbee '''

# %%
Art_related_words = ''' portraiture POP artless artful artistic calligraphy sculpture topiary design cinema cookery abstraction
dance dance statecraft painting choreography minstrelsy dramaturgy gastronomy paint oratory critique versification song cartography oil painting rhetoric
mime campanology puppetry pedagogy drawing represent horology techno- penmanship didactics architecture aviation embroidery erotica critic drama '''

# %%
Health_related_words = '''disease obesity world health organization medicine nutrition well-being exercise welfare wellness health care public health 
                     nursing stress safety hygiene research social healthy condition aids epidemiology healthiness wellbeing
                     care illness medical dieteducation infectious disease environmental healthcare physical fitness hospitals 
                     health care provider doctors healthy community design insurance sanitation human body patient mental health
                      medicare agriculture health science fitnesshealth policy  weight loss physical therapy psychology pharmacy
                     metabolic organism human lifestyle status unhealthy upbeat vaccination sleep condom alcohol smoking water family
                     eudaimonia eudaemonia air house prevention genetics public families poor needs treatment communicable disease 
                     study protection malaria development food priority management healthful mental provide department administration
                     programs help assistance funding environment improving emergency need program affected schools private mental illness 
                     treat diseases preparedness perinatal fertility sickness veterinary sanitary pharmacists behavioral midwives
                     gerontology infertility hospitalization midwifery cholesterol childcare pediatrician pediatrics medicaid asthma 
                     pensions sicknesses push-up physical education body-mass-index eat well gymnastic apparatus tune up good morning 
                     bathing low blood-pressure heart attack health club ride-bike you feel good eczema urticaria dermatitis sunburn overwork 
                     manufacturing medical sociology covid-19 cancer  '''

# %%
DataSience_related_words = ''' Anonymization Algorithm Artificial Intelligence Bayes Theorem Behavioural 
analytics Big Data Citizen Data Scientist Classification Clickstream analytics Clustering Data Governance 
Data Mining Data Set Data Scientist Decision Trees Democratization of Data Science Dimension In-Memory
Database Metadata Python R Random Forest Standard Deviation Back End Statistic vs. Statistics Data Engineering 
Data Journalism Data Visualization Correlation Data Pipelines Data Wrangling (Munging) ETL (Extract, Transform, Load) Deep 
Learning Feature Engineering Feature Selection Neural Networks Supervised Machine Learning Unsupervised Machine Learning 
                         '''

# %% [markdown]
# ## Preprocessing the sets
# * ### Tokenizing and removing stop words from the sets

# %%
import en_core_web_sm
from nltk.tokenize import RegexpTokenizer, WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import string
nlp = en_core_web_sm.load()
tokenizer = RegexpTokenizer(r'\w+')
lemmatizer = WordNetLemmatizer()
stop = set(stopwords.words('english'))
punctuation = list(string.punctuation)
stop.update(punctuation)
w_tokenizer = WhitespaceTokenizer()

# clean the set of words
            
def furnished(text):
    final_text = []
    for i in text.split():
        if i.lower() not in stop:
            word = lemmatizer.lemmatize(i)
            final_text.append(word.lower())
    return " ".join(final_text)

# %%
# apply the furnished function on our sets
Sport = furnished(Sport_related_words)
Art = furnished(Art_related_words)
Health = furnished(Health_related_words)
DataSience = furnished(DataSience_related_words)

# %% [markdown]
# #### Removing duplicates

# %%
# delete duplicates
string1 = Sport
words = string1.split()
Sport = " ".join(sorted(set(words), key=words.index))
Sport
# Out:
# 'aerobics archer archery arena arrowathlete athletics axel sport badminton ballbasebase ballbasketball batbaton batter batting biathlon bicycle bicycling bike biking billiards bobsleigh bocce boomerang boule bowbowler bowling boxer boxing bronzemedalbunt canoe canoeing catch catcherchampion championship cleat club coach compete competingcompetition competitor crew cricket croquetcross countrycuecurling cyclecy cling cyclist dart dartboard deadlifting decathlon defense diamond discus divediver divingdo dgeball doubleheader dugout épéeequestrian equipment exercise fencing field hockey fielder fielding figure skatingfitness football forwardfree throwfrisbee'

# %%
# delete duplicates
string2 = Art
words = string2.split()
Art = " ".join(sorted(set(words), key=words.index))
Art
# Out:
# 'portraiture pop artless artful artistic calligraphy sculpture topiary design cinema cookery abstraction dance statecraft painting choreography minstrelsy dramaturgy gastronomy paint oratory critique versification song cartography oil rhetoric mime campanology puppetry pedagogy drawing represent horology techno- penmanship didactics architecture aviation embroidery erotica critic drama'

# %%
# delete duplicates
string3 = Health
words = string3.split()
Health = " ".join(sorted(set(words), key=words.index))
Health
# Out:
# 'disease obesity world health organization medicine nutrition well-being exercise welfare wellness care public nursing stress safety hygiene research social healthy condition aid epidemiology healthiness wellbeing illness medical dieteducation infectious environmental healthcare physical fitness hospital provider doctor community design insurance sanitation human body patient mental medicare agriculture science fitnesshealth policy weight loss therapy psychology pharmacy metabolic organism lifestyle status unhealthy upbeat vaccination sleep condom alcohol smoking water family eudaimonia eudaemonia air house prevention genetics poor need treatment communicable study protection malaria development food priority management healthful provide department administration program help assistance funding environment improving emergency affected school private treat preparedness perinatal fertility sickness veterinary sanitary pharmacist behavioral midwife gerontology infertility hospitalizatio
# ...

# %%
# delete duplicates
string4 = DataSience
words = string4.split()
DataSience = " ".join(sorted(set(words), key=words.index))
DataSience
# Out:
# 'anonymization algorithm artificial intelligence bayes theorem behavioural analytics big data citizen scientist classification clickstream clustering governance mining set decision trees democratization science dimension in-memory database metadata python r random forest standard deviation back end statistic vs. statistics engineering journalism visualization correlation pipelines wrangling (munging) etl (extract, transform, load) deep learning feature selection neural networks supervised machine unsupervised'

# %% [markdown]
# #### Jaccard Similarity

# %%
'''Jaccard similarity is good for cases where duplication does not matter, 
cosine similarity is good for cases where duplication matters while analyzing text similarity. For two product descriptions, 
it will be better to use Jaccard similarity as repetition of a word does not reduce their similarity.'''

def jaccard_similarity(query, document):
    intersection = set(query).intersection(set(document))
    union = set(query).union(set(document))
    return len(intersection)/len(union)
def get_scores(group,Tweets):
    scores = []
    for Tweets in Tweets:
        s = jaccard_similarity(group, Tweets)
        scores.append(s)
    return scores

# %%
# Sport scores
Sport_scores = get_scores(Sport, Tweets.Tweets.to_list())
Sport_scores[-10:]
# Out:
# [0.7586206896551724,
#  0.7931034482758621,
#  0.6875,
#  0.8928571428571429,
#  0.7666666666666667,
#  0.7586206896551724,
#  0.6774193548387096,
#  0.7419354838709677,
#  0.7666666666666667,
#  0.7333333333333333]

# %%
# Art scores
Art_scores = get_scores(Art, Tweets.Tweets.to_list())
Art_scores[-10:]
# Out:
# [0.75,
#  0.7857142857142857,
#  0.7333333333333333,
#  0.8214285714285714,
#  0.7586206896551724,
#  0.75,
#  0.7241379310344828,
#  0.7333333333333333,
#  0.7586206896551724,
#  0.7857142857142857]

# %%
# Health scores
Health_scores = get_scores(Health, Tweets.Tweets.to_list())
Health_scores[-10:]
# Out:
# [0.7333333333333333,
#  0.7666666666666667,
#  0.71875,
#  0.8620689655172413,
#  0.7419354838709677,
#  0.7333333333333333,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.8620689655172413,
#  0.7096774193548387]

# %%
 # DataSience scores
DataSience_scores = get_scores(DataSience, Tweets.Tweets.to_list())
DataSience_scores[-10:]
# Out:
# [0.71875,
#  0.696969696969697,
#  0.6111111111111112,
#  0.78125,
#  0.7272727272727273,
#  0.71875,
#  0.6,
#  0.6111111111111112,
#  0.6764705882352942,
#  0.6470588235294118]

# %%
Df  = {'Tweets':Tweets.Tweets.to_list(), 'Sport_scores':Sport_scores,
         'Art_scores': Art_scores, 'Health_scores':Health_scores, 'DataSience_scores':DataSience_scores}
scores_df = pd.DataFrame(Df)
scores_df.head(20)
# Out:
#                                                Tweets  Sport_scores  \
# 0   telegraphsport fatimakdouh paul who inhookwetr...      0.740741
# 1   craig macgillivray what a save big chance pomp...      0.724138
# 2   coachholst thats why 4 short seasons w some st...      0.800000
# 3    bloominanna i cannot think of a better metaph...      0.733333
# 4    duncanbrownejpi josh askew unveiled by new cl...      0.793103
# 5   please god dont make me like this sport abeg i...      0.740741
# 6    jlcbasketball our international studentathlet...      0.612903
# 7    castortroysrb some of my favourite pictures f...      0.793103
# 8    trboxing congratulations to andreward on his ...      0.677419
# 9    trboxing congratulations to 2021 boxinghall i...      0.750000
# 10   flashysillah 🆕 margs vs nsg mobo awards racis...      0.727273
# 11   officialj0nn bleacherreport brfootball brgami...      0.647059
# 12   feiglobal heres to a legend that changed the ...      0.750000
# ...

# %%
#assigning of classes to the tweets

def get_clusters(l1, l2, l3, l4):
    spor = []
    art = []
    heal = []
    datas = []
    for i, j, k, l in zip(l1, l2, l3, l4):
        m = max(i, j, k, l)
        if m == i:
            spor.append(1)
        else:
            spor.append(0)
        if m == j:
            art.append(1)
        else:
            art.append(0)        
        if m == k:
            heal.append(1)
        else:
            heal.append(0)  
        if m == l:
            datas.append(1)
        else:
            datas.append(0)   
            
    return spor, art, heal, datas

# %%
l1 = scores_df.Sport_scores.to_list()
l2 = scores_df.Art_scores.to_list()
l3 = scores_df.Health_scores.to_list()
l4 = scores_df.DataSience_scores.to_list()
spor, art, heal, datas = get_clusters(l1, l2, l3, l4)

# %%
Df  = {'Tweets':Tweets.Tweets.to_list(), 'Sport':spor,
         'Art': art, 'Health':heal, 'DataSience':datas}
cluster_df = pd.DataFrame(Df)
cluster_df.head(100)
# Out:
#                                                Tweets  Sport  Art  Health  \
# 0   telegraphsport fatimakdouh paul who inhookwetr...      0    1       0
# 1   craig macgillivray what a save big chance pomp...      0    1       0
# 2   coachholst thats why 4 short seasons w some st...      1    0       0
# 3    bloominanna i cannot think of a better metaph...      0    1       0
# 4    duncanbrownejpi josh askew unveiled by new cl...      0    1       0
# ..                                                ...    ...  ...     ...
# 95  man city get green light for lionel messi tran...      0    1       0
# 96  atanasiocharles kylejengel firetrumptoday dine...      0    0       1
# 97   philhurst1 i am very proud to contribute to s...      0    1       0
# 98  ignorance of the crowd not giving one iota of ...      1    0       0
# 99  🆕 margs vs nsg mobo awards racism in sport 🗞 a...      1    0       0
#
#     DataSience
# 0            0
# 1            0
# 2            0
# ...

# %%
#calculate the total number in each category
pivot_clusters = cluster_df.groupby(['Tweets']).sum()
pivot_clusters['Sport'] = pivot_clusters['Sport'].astype(int)
pivot_clusters['Art'] = pivot_clusters['Art'].astype(int)
pivot_clusters['Health'] = pivot_clusters['Health'].astype(int)
pivot_clusters['DataSience'] = pivot_clusters['DataSience'].astype(int)
pivot_clusters['total'] = pivot_clusters['DataSience'] + pivot_clusters['Health'] + pivot_clusters['Art'] +  pivot_clusters['Sport']
pivot_clusters.loc["Total"] = pivot_clusters.sum()  #add a totals row
print(pivot_clusters.shape)
pivot_clusters.tail(100)
# Out:
# (10406, 5)
#                                                     Sport   Art  Health  \
# Tweets
# ‘dynamite’ official mv is now the most viewed m...      0     1       0
# ‘not going to crush me’ frontline nurse diagnos...      0     0       1
# ‘planet 9’ by rosemcgowan httpstcoz7r9oh4cdc            0     0       1
# ‘you can get data from nmr in just two or three...      0     1       0
# ⁦theblaxican97⁩ feeling this albums vibes today...      0     0       1
# ...                                                   ...   ...     ...
# 🤷‍♂️ oh well everyone said tell people tell peo...      0     1       0
# 🥺 aww lemme go listen to some music                     0     1       0
# 🦉 yeswecrann has delivered his first half playe...      0     1       0
# 🦠great to see ⁦lfc⁩ encouraging supporters luck...      1     0       0
# Total                                                4843  7932    2129
#
#                                                     DataSience  total
# Tweets
# ...

# %% [markdown]
# ## Kmeans
#   . k-means clustering is a method of vector quantization, originally from signal processing, that aims to partition n observations into k clusters in which each observation belongs to the cluster with the nearest mean (cluster centers or cluster centroid), serving as a prototype of the cluster.

# %% [markdown]
# * #### Sport and Health

# %%
from sklearn.cluster import KMeans

# %%
X = pivot_clusters[['Sport', 'Health']].values
# Using the elbow method to find the optimal number of clusters
# Elbow Method
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=300, random_state=0)
    kmeans.fit(X)
    #appending the WCSS to the list (kmeans.inertia_ returns the WCSS value for an initialized cluster)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('wcss')
plt.show()

# %%
# fitting kmeans to dataset
kmeans = KMeans(n_clusters=2, init='k-means++', n_init=10, max_iter=300, random_state=0)
Y_kmeans = kmeans.fit_predict(X)
# Visualising the clusters
plt.scatter(X[Y_kmeans==0, 0], X[Y_kmeans==0, 1], s=200, c='blue', label= 'Cluster 1')
plt.scatter(X[Y_kmeans==1, 0], X[Y_kmeans==1, 1], s=200, c='brown', label= 'Cluster 2')
#plt.scatter(X[Y_kmeans==2, 0], X[Y_kmeans==2, 1], s=200, c='green', label= 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=30, c='violet', label='Centroids' )
plt.title('Clusters of tweets in Health and Sport groups')
plt.xlabel('social tweets')
plt.ylabel('health tweets')
plt.legend()
plt.show()

# %% [markdown]
# * #### Art and Health

# %%
X = pivot_clusters[['Art', 'Health']].values
# Using the elbow method to find the optimal number of clusters
# Elbow Method
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=300, random_state=0)
    kmeans.fit(X)
    #appending the WCSS to the list (kmeans.inertia_ returns the WCSS value for an initialized cluster)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('wcss')
plt.show()

# %%
# fitting kmeans to dataset
kmeans = KMeans(n_clusters=2, init='k-means++', n_init=10, max_iter=300, random_state=0)
Y_kmeans = kmeans.fit_predict(X)
# Visualising the clusters
plt.scatter(X[Y_kmeans==0, 0], X[Y_kmeans==0, 1], s=200, c='blue', label= 'Cluster 1')
plt.scatter(X[Y_kmeans==1, 0], X[Y_kmeans==1, 1], s=200, c='brown', label= 'Cluster 2')
#plt.scatter(X[Y_kmeans==2, 0], X[Y_kmeans==2, 1], s=200, c='green', label= 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=30, c='violet', label='Centroids' )
plt.title('Clusters of tweets in Health and Art groups')
plt.xlabel('art tweets')
plt.ylabel('health tweets')
plt.legend()
plt.show()

# %% [markdown]
# * #### DataSience and Health

# %%
X = pivot_clusters[['DataSience', 'Health']].values
# Using the elbow method to find the optimal number of clusters
# Elbow Method
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=300, random_state=0)
    kmeans.fit(X)
    #appending the WCSS to the list (kmeans.inertia_ returns the WCSS value for an initialized cluster)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('wcss')
plt.show()

# %%
# fitting kmeans to dataset
kmeans = KMeans(n_clusters=2, init='k-means++', n_init=10, max_iter=300, random_state=0)
Y_kmeans = kmeans.fit_predict(X)
# Visualising the clusters
plt.scatter(X[Y_kmeans==0, 0], X[Y_kmeans==0, 1], s=200, c='blue', label= 'Cluster 1')
plt.scatter(X[Y_kmeans==1, 0], X[Y_kmeans==1, 1], s=200, c='brown', label= 'Cluster 2')
#plt.scatter(X[Y_kmeans==2, 0], X[Y_kmeans==2, 1], s=200, c='green', label= 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=30, c='violet', label='Centroids' )
plt.title('Clusters of tweets in Health and DataSience groups')
plt.xlabel('datasience tweets')
plt.ylabel('health tweets')
plt.legend()
plt.show()
